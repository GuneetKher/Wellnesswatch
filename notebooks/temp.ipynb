# %%
import pandas as pd

# %%
mh = pd.read_csv('../data/Consolidatedmh.csv')

# %%
mh[mh['Flair']=='Guest AMA']['Text']
# Out:
# 61636    Super exciting news, everyone!!! We want to an...
# Name: Text, dtype: object

# %%
mh[mh['Flair']=='💬General DBT Post']['Text']
# Out:
# 72657    Disclaimer: I am not a lawyer or an expert, I ...
# 73103                                            [removed]
# 73282                                            [removed]
# 73378    if anyone has gone through dbt can you tell me...
# 73390    Do you guys bite your nails? It may sound stup...
# 73421                                            [removed]
# 73751    I’ve been studying internet conflict dynamics ...
# 74269    I suspected that I was dealing with bpd for ov...
# 75051                                            [removed]
# 75207                                            [removed]
# 75220    I have the choice between leaving my drama gro...
# 75604    It’s so stupid. The questions are stupid. They...
# 75638                                            [removed]
# 75681    Hello. I have not been diagnosed yet, and I've...
# 75826    Hello! BPD baby here, whose really been trying...
# 76018    If you're not in the right state of mind for D...
# ...

# %%
mh['Flair'].unique()
# Out:
# array(['Opinion / Thought / Idea / Discussion ', 'Rant / Vent',
#        'Medication ', 'Work / School ', 'Advice / Encouragement',
#        'Undiagnosed Questions', 'Seeking Support', 'Trigger Warning',
#        'Delusions', 'Introduction / New Member 👋', 'Help A Loved One',
#        'Suicidal Thoughts', 'Progress / Good News ☀️', 'Art', 'Video',
#        'Community Improvement / Ideas', 'Hallucinations / Delusions',
#        'Meme', 'Vitamin/Supplement ', 'Hallucinations',
#        'Negative Symptoms', 'Relationships ', 'Pro Tip', 'Selfie ',
#        'News, Articles, Journals', 'Music', 'Resources / Literature',
#        'Disorganized Thoughts', 'Tobacco / Alcohol / Drugs',
#        'Therapist / Doctors', 'Food and recipes',
#        'Questions/Advice/Support', 'Articles/Information',
#        'Seeking Empathy / Support', 'Tips/Suggestions',
#        'Obsession Sharing!', 'Success/Celebration', 'Reminder',
#        'Accountability', 'Megathread: Weekly Wins',
# ...
